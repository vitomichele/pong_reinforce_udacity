# %% [markdown]
# # Welcome!
# Below, we will learn to implement and train a policy to play atari-pong, using only the pixels as input. We will use convolutional neural nets, multiprocessing, and pytorch to implement and train our policy. Let's get started!
#
# (I strongly recommend you to try this notebook on the Udacity workspace first before running it locally on your desktop/laptop, as performance might suffer in different environments)

# %%
# install package for displaying animation
# !pip install JSAnimation

# custom utilies for displaying animation, collecting rollouts and more
import pong_utils

# %matplotlib inline

# check which device is being used. 
# I recommend disabling gpu until you've made sure that the code runs
device = pong_utils.device
print("using device: ",device)
# Out:
# Requirement already satisfied: JSAnimation in /opt/conda/lib/python3.6/site-packages (0.1)
# using device:  cuda:0

# %%
# render ai gym environment
import gym
import time

# PongDeterministic does not contain random frameskip
# so is faster to train than the vanilla Pong-v4 environment
env = gym.make('PongDeterministic-v4')

print("List of available actions: ", env.unwrapped.get_action_meanings())

# we will only use the actions 'RIGHTFIRE' = 4 and 'LEFTFIRE" = 5
# the 'FIRE' part ensures that the game starts again after losing a life
# the actions are hard-coded in pong_utils.py
# Out:
# List of available actions:  ['NOOP', 'FIRE', 'RIGHT', 'LEFT', 'RIGHTFIRE', 'LEFTFIRE']

# %% [markdown]
# # Preprocessing
# To speed up training, we can simplify the input by cropping the images and use every other pixel

# %%
import matplotlib
import matplotlib.pyplot as plt

# show what a preprocessed image looks like
env.reset()
_, _, _, _ = env.step(0)
# get a frame after 20 steps
for _ in range(20):
    frame, _, _, _ = env.step(1)

plt.subplot(1,2,1)
plt.imshow(frame)
plt.title('original image')

plt.subplot(1,2,2)
plt.title('preprocessed image')

# 80 x 80 black and white image
plt.imshow(pong_utils.preprocess_single(frame), cmap='Greys')
plt.show()

# %% [markdown]
# # Policy
#
# ## Exercise 1: Implement your policy
#
# Here, we define our policy. The input is the stack of two different frames (which captures the movement), and the output is a number $P_{\rm right}$, the probability of moving left. Note that $P_{\rm left}= 1-P_{\rm right}$

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F



# set up a convolutional neural net
# the output is the probability of moving right
# P(left) = 1-P(right)
class Policy(nn.Module):

    def __init__(self):
        super(Policy, self).__init__()      
        # 80x80 to outputsize x outputsize
        # outputsize = (inputsize - kernel_size + stride)/stride 
        # (round up if not an integer)

        self.conv1 = nn.Conv2d(2, 4, kernel_size=3, stride=3)
        # 80 / 3 = 26
        self.conv2 = nn.Conv2d(4, 8, kernel_size=3, stride=3)
        # 26 / 3 = 8
        self.size=8*8*8
        
        # 1 fully connected layer
        self.fc1 = nn.Linear(self.size, 256)
        self.fc2 = nn.Linear(256, 1)
        self.sig = nn.Sigmoid()
        
    def forward(self, x):   
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        # flatten the tensor
        x = x.view(-1,self.size)
        x = F.relu(self.fc1(x))
        return self.sig(self.fc2(x))

# use your own policy!
policy=Policy().to(device)


# we use the adam optimizer with learning rate 2e-4
# optim.SGD is also possible
import torch.optim as optim
optimizer = optim.Adam(policy.parameters(), lr=1e-4)

# %% [markdown]
# # Game visualization
# pong_utils contain a play function given the environment and a policy. An optional preprocess function can be supplied. Here we define a function that plays a game and shows learning progress

# %%
pong_utils.play(env, policy, time=100, preprocess=pong_utils.preprocess_single) 
# try to add the option "preprocess=pong_utils.preprocess_single"
# to see what the agent sees
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgROSWOFGGJYIOKNLH">
#     <br>
#     <input id="_anim_sliderROSWOFGGJYIOKNLH" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animROSWOFGGJYIOKNLH.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animROSWOFGGJYIOKNLH.slower()">&#8211;</button>
#     <button onclick="animROSWOFGGJYIOKNLH.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animROSWOFGGJYIOKNLH.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animROSWOFGGJYIOKNLH.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animROSWOFGGJYIOKNLH.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animROSWOFGGJYIOKNLH.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animROSWOFGGJYIOKNLH.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animROSWOFGGJYIOKNLH.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animROSWOFGGJYIOKNLH.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectROSWOFGGJYIOKNLH" class="anim_control">
#     <input type="radio" name="state" value="once" checked> Once </input>
#     <input type="radio" name="state" value="loop" > Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgROSWOFGGJYIOKNLH";
#     var slider_id = "_anim_sliderROSWOFGGJYIOKNLH";
#     var loop_select_id = "_anim_loop_selectROSWOFGGJYIOKNLH";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %% [markdown]
# # Rollout
# Before we start the training, we need to collect samples. To make things efficient we use parallelized environments to collect multiple examples at once

# %%
envs = pong_utils.parallelEnv('PongDeterministic-v4', n=4, seed=12345)
prob, state, action, reward = pong_utils.collect_trajectories(envs, policy, tmax=10)

# %%
print(prob)
# Out:
# [array([ 0.50807661,  0.50807661,  0.49190551,  0.49185646], dtype=float32), array([ 0.49184233,  0.50815767,  0.49189502,  0.49206561], dtype=float32), array([ 0.50820327,  0.50819379,  0.49202877,  0.49214125], dtype=float32), array([ 0.50815171,  0.50819165,  0.49196178,  0.50811112], dtype=float32), array([ 0.49181855,  0.4918077 ,  0.5080806 ,  0.49185491], dtype=float32), array([ 0.50832397,  0.49174809,  0.5081085 ,  0.49178684], dtype=float32), array([ 0.49163741,  0.50818467,  0.50818515,  0.49196774], dtype=float32), array([ 0.50813758,  0.49183625,  0.49208874,  0.50795913], dtype=float32), array([ 0.49186271,  0.50795007,  0.49189103,  0.50786173], dtype=float32), array([ 0.49156809,  0.50846589,  0.50815672,  0.50826532], dtype=float32)]

# %% [markdown]
# # Function Definitions
# Here you will define key functions for training.
#
# ## Exercise 2: write your own function for training
# (this is the same as policy_loss except the negative sign)
#
# ### REINFORCE
# you have two choices (usually it's useful to divide by the time since we've normalized our rewards and the time of each trajectory is fixed)
#
# 1. $\frac{1}{T}\sum^T_t R_{t}^{\rm future}\log(\pi_{\theta'}(a_t|s_t))$
# 2. $\frac{1}{T}\sum^T_t R_{t}^{\rm future}\frac{\pi_{\theta'}(a_t|s_t)}{\pi_{\theta}(a_t|s_t)}$ where $\theta'=\theta$ and make sure that the no_grad is enabled when performing the division

# %%
import numpy as np
def surrogate(policy, old_probs, states, actions, rewards,
              discount = 0.995, beta=0.01):

    # Future rewards from rewards and discount
    
    discount = discount**np.arange(len(rewards))
    rewards = np.asarray(rewards)*discount[:,np.newaxis]
    rewards_future = rewards[::-1].cumsum(axis=0)[::-1]
    
    mean = np.mean(rewards_future, axis=1)
    std = np.std(rewards_future, axis=1) + 1.0e-10

    rewards_normalized = (rewards_future - mean[:,np.newaxis])/std[:,np.newaxis]
    
    
    actions = torch.tensor(actions, dtype=torch.int8, device=device)
    old_probs = torch.tensor(old_probs, dtype=torch.float, device=device)
    rewards = torch.tensor(rewards_normalized, dtype=torch.float, device=device)

    
    # convert states to policy (or probability)
    new_probs = pong_utils.states_to_prob(policy, states)
    new_probs = torch.where(actions == pong_utils.RIGHT, new_probs, 1.0-new_probs)
    
    with torch.no_grad():
        ratio = (new_probs + 1.0e-10)/ (old_probs + 1.0e-10)

    # include a regularization term
    # this steers new_policy towards 0.5
    # which prevents policy to become exactly 0 or 1
    # this helps with exploration
    # add in 1.e-10 to avoid log(0) which gives nan
    entropy = -(new_probs*torch.log(old_probs+1.e-10)+(1.0-new_probs)*torch.log(1.0-old_probs+1.e-10))

    #print(ratio)
    #print(rewards)
    
    return torch.mean(ratio * rewards + beta*entropy)

#print("policy: {}" .format(policy))
#print("prob: {}" .format(prob))
#print("state: {}" .format(state))
#print("action: {}" .format(action))
#print("reward: {}" .format(reward))
Lsur= surrogate(policy, prob, state, action, reward)

print(Lsur)
# Out:
# tensor(1.00000e-03 *
#        6.9301, device='cuda:0')

# %% [markdown]
# # Training
# We are now ready to train our policy!
# WARNING: make sure to turn on GPU, which also enables multicore processing. It may take up to 45 minutes even with GPU enabled, otherwise it will take much longer!

# %%
#policy = torch.load('REINFORCE_01.policy')

# %%
from parallelEnv import parallelEnv
import numpy as np
# WARNING: running through all 800 episodes will take 30-45 minutes

# training loop max iterations
episode = 500

# widget bar to display progress
# !pip install progressbar
import progressbar as pb
widget = ['training loop: ', pb.Percentage(), ' ', 
          pb.Bar(), ' ', pb.ETA() ]
# initialize environment
envs = parallelEnv('PongDeterministic-v4', n=8, seed=1234)


discount_rate = .99
beta = .01

# keep track of progress
mean_rewards = []
for i in range(0, 3):
    timer = pb.ProgressBar(widgets=widget, maxval=episode).start()
    tmax = 100+100*i

    for e in range(episode):

        # collect trajectories
        old_probs, states, actions, rewards = \
            pong_utils.collect_trajectories(envs, policy, tmax=tmax)

        total_rewards = np.sum(rewards, axis=0)

        # this is the SOLUTION!
        # use your own surrogate function
        L = -surrogate(policy, old_probs, states, actions, rewards, beta=beta)

        # L = -pong_utils.surrogate(policy, old_probs, states, actions, rewards, beta=beta)
        optimizer.zero_grad()
        L.backward()
        optimizer.step()
        del L

        # the regulation term also reduces
        # this reduces exploration in later runs
        beta*=.995

        # get the average reward of the parallel environments
        mean_rewards.append(np.mean(total_rewards))

        # display some progress every 20 iterations
        if (e+1)%20 ==0 :
            print("Episode: {0:d}, score: {1:f}".format(e+1,np.mean(total_rewards)))
            print(total_rewards)

        # update progress widget bar
        timer.update(e+1)
        
        torch.save(policy,  'REINFORCE_0'+str(i)+'.policy')
        plt.plot(mean_rewards)
        
    timer.finish()
plt.plot(mean_rewards)
# Out:
# Requirement already satisfied: progressbar in /opt/conda/lib/python3.6/site-packages (2.5)
# /opt/conda/lib/python3.6/site-packages/torch/serialization.py:193: UserWarning: Couldn't retrieve source code for container of type Policy. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# training loop:   4% |#                                          | ETA:  0:12:45
# Episode: 20, score: -3.625000
# [-4. -5. -2. -3. -4. -5. -1. -5.]
# training loop:   8% |###                                        | ETA:  0:12:12
# Episode: 40, score: -4.375000
# [-5. -3. -4. -5. -4. -5. -5. -4.]
# training loop:  12% |#####                                      | ETA:  0:11:40
# Episode: 60, score: -3.125000
# [-1. -5. -5. -1. -5. -3. -2. -3.]
# training loop:  16% |######                                     | ETA:  0:11:08
# Episode: 80, score: -4.375000
# [-4. -5. -5. -4. -4. -4. -4. -5.]
# training loop:  20% |########                                   | ETA:  0:10:36
# Episode: 100, score: -3.500000
# [-4. -5. -5. -1. -2. -4. -3. -4.]
# training loop:  24% |##########                                 | ETA:  0:10:04
# Episode: 120, score: -4.250000
# [-4. -4. -3. -5. -5. -3. -5. -5.]
# training loop:  28% |############                               | ETA:  0:09:32
# Episode: 140, score: -3.875000
# [-4. -4. -5. -5. -3. -1. -5. -4.]
# training loop:  32% |#############                              | ETA:  0:09:00
# Episode: 160, score: -4.250000
# [-3. -4. -4. -5. -5. -5. -5. -3.]
# training loop:  36% |###############                            | ETA:  0:08:29
# Episode: 180, score: -4.125000
# [-5. -3. -4. -5. -5. -3. -5. -3.]
# training loop:  40% |#################                          | ETA:  0:07:57
# Episode: 200, score: -4.750000
# [-5. -5. -5. -4. -4. -5. -5. -5.]
# training loop:  44% |##################                         | ETA:  0:07:25
# Episode: 220, score: -4.250000
# [-5. -4. -4. -5. -1. -5. -5. -5.]
# training loop:  48% |####################                       | ETA:  0:06:53
# Episode: 240, score: -4.375000
# [-4. -5. -5. -5. -4. -5. -3. -4.]
# training loop:  52% |######################                     | ETA:  0:06:22
# Episode: 260, score: -4.500000
# [-4. -4. -5. -5. -4. -4. -5. -5.]
# training loop:  56% |########################                   | ETA:  0:05:50
# Episode: 280, score: -4.000000
# [-5. -3. -3. -4. -5. -5. -4. -3.]
# training loop:  60% |#########################                  | ETA:  0:05:18
# Episode: 300, score: -4.125000
# [-2. -3. -5. -4. -5. -5. -5. -4.]
# training loop:  64% |###########################                | ETA:  0:04:46
# Episode: 320, score: -4.375000
# [-5. -5. -3. -4. -5. -5. -5. -3.]
# training loop:  68% |#############################              | ETA:  0:04:14
# Episode: 340, score: -3.625000
# [-5. -5. -4. -1. -3. -3. -5. -3.]
# training loop:  72% |##############################             | ETA:  0:03:42
# Episode: 360, score: -3.625000
# [-5. -4. -5. -3. -3. -1. -4. -4.]
# training loop:  76% |################################           | ETA:  0:03:11
# Episode: 380, score: -4.125000
# [-4. -4. -5. -4. -5. -5. -3. -3.]
# training loop:  80% |##################################         | ETA:  0:02:39
# Episode: 400, score: -4.375000
# [-5. -5. -5. -4. -3. -4. -4. -5.]
# training loop:  84% |####################################       | ETA:  0:02:07
# Episode: 420, score: -4.000000
# [-4. -5. -4. -3. -3. -4. -5. -4.]
# training loop:  88% |#####################################      | ETA:  0:01:35
# Episode: 440, score: -3.625000
# [-1. -3. -1. -5. -5. -5. -5. -4.]
# training loop:  92% |#######################################    | ETA:  0:01:03
# Episode: 460, score: -4.125000
# [-5. -3. -3. -4. -5. -3. -5. -5.]
# training loop:  96% |#########################################  | ETA:  0:00:31
# Episode: 480, score: -4.000000
# [-4. -5. -3. -3. -3. -4. -5. -5.]
# training loop: 100% |###########################################| Time: 0:13:15
# training loop:   0% |                                          | ETA:  --:--:--
# Episode: 500, score: -4.625000
# [-5. -4. -4. -5. -5. -5. -4. -5.]
# training loop:   4% |#                                          | ETA:  0:24:36
# Episode: 20, score: -8.500000
# [ -7. -10.  -9.  -9. -10.  -6.  -7. -10.]
# training loop:   8% |###                                        | ETA:  0:23:33
# Episode: 40, score: -9.875000
# [-10. -10. -10. -10.  -9. -10. -10. -10.]
# training loop:  12% |#####                                      | ETA:  0:22:33
# Episode: 60, score: -8.375000
# [ -8. -10.  -7.  -4. -10.  -9.  -9. -10.]
# training loop:  16% |######                                     | ETA:  0:21:32
# Episode: 80, score: -9.000000
# [ -9.  -9. -10. -10.  -8. -10.  -7.  -9.]
# training loop:  20% |########                                   | ETA:  0:20:29
# Episode: 100, score: -9.500000
# [-10. -10.  -9.  -7. -10. -10. -10. -10.]
# training loop:  24% |##########                                 | ETA:  0:19:28
# Episode: 120, score: -8.125000
# [ -9.  -8.  -7.  -9.  -9.  -7. -10.  -6.]
# training loop:  28% |############                               | ETA:  0:18:26
# Episode: 140, score: -9.500000
# [ -9. -10. -10. -10. -10.  -8.  -9. -10.]
# training loop:  32% |#############                              | ETA:  0:17:24
# Episode: 160, score: -9.750000
# [-10.  -9.  -9. -10. -10. -10. -10. -10.]
# training loop:  36% |###############                            | ETA:  0:16:23
# Episode: 180, score: -9.000000
# [-10.  -8. -10.  -9.  -8. -10.  -8.  -9.]
# training loop:  40% |#################                          | ETA:  0:15:23
# Episode: 200, score: -7.750000
# [ -5.  -5.  -9.  -7. -10.  -8.  -8. -10.]
# training loop:  44% |##################                         | ETA:  0:14:24
# Episode: 220, score: -7.125000
# [ -3.  -9.  -8.  -8.  -3.  -6. -10. -10.]
# training loop:  48% |####################                       | ETA:  0:13:22
# Episode: 240, score: -8.625000
# [ -9. -10.  -9.  -9.  -7.  -7.  -8. -10.]
# training loop:  52% |######################                     | ETA:  0:12:20
# Episode: 260, score: -9.375000
# [-10.  -7. -10. -10. -10. -10. -10.  -8.]
# training loop:  56% |########################                   | ETA:  0:11:18
# Episode: 280, score: -9.750000
# [-10. -10. -10. -10. -10. -10.  -9.  -9.]
# training loop:  60% |#########################                  | ETA:  0:10:16
# Episode: 300, score: -8.500000
# [ -8.  -9.  -9. -10.  -5. -10.  -9.  -8.]
# training loop:  64% |###########################                | ETA:  0:09:14
# Episode: 320, score: -9.125000
# [ -9. -10. -10. -10. -10. -10.  -5.  -9.]
# training loop:  68% |#############################              | ETA:  0:08:12
# Episode: 340, score: -7.500000
# [ -7.  -5.  -9.  -6.  -9.  -8. -10.  -6.]
# training loop:  72% |##############################             | ETA:  0:07:10
# Episode: 360, score: -8.125000
# [ -6.  -4.  -9.  -9.  -9. -10. -10.  -8.]
# training loop:  76% |################################           | ETA:  0:06:09
# Episode: 380, score: -8.250000
# [ -9.  -6. -10. -10.  -7.  -8.  -7.  -9.]
# training loop:  80% |##################################         | ETA:  0:05:07
# Episode: 400, score: -8.250000
# [ -7.  -3. -10. -10.  -8.  -9. -10.  -9.]
# training loop:  84% |####################################       | ETA:  0:04:05
# Episode: 420, score: -9.500000
# [-10. -10. -10. -10.  -9.  -9. -10.  -8.]
# training loop:  88% |#####################################      | ETA:  0:03:04
# Episode: 440, score: -9.625000
# [ -9. -10. -10. -10. -10.  -8. -10. -10.]
# training loop:  92% |#######################################    | ETA:  0:02:02
# Episode: 460, score: -7.875000
# [ -8.  -7. -10. -10.  -6.  -6.  -7.  -9.]
# training loop:  96% |#########################################  | ETA:  0:01:01
# Episode: 480, score: -8.000000
# [ -5. -10.  -4.  -8. -10.  -8. -10.  -9.]
# training loop: 100% |###########################################| Time: 0:25:33
# training loop:   0% |                                          | ETA:  --:--:--
# Episode: 500, score: -7.500000
# [ -5.  -7.  -9. -10.  -9.  -8.  -6.  -6.]
# training loop:   4% |#                                          | ETA:  0:36:00
# Episode: 20, score: -13.750000
# [-13. -15. -12. -14. -13. -15. -16. -12.]
# training loop:   8% |###                                        | ETA:  0:34:28
# Episode: 40, score: -15.125000
# [-16. -13. -15. -16. -16. -15. -14. -16.]
# training loop:  12% |#####                                      | ETA:  0:32:59
# Episode: 60, score: -13.625000
# [-14. -15. -13. -14.  -9. -15. -16. -13.]
# training loop:  16% |######                                     | ETA:  0:31:30
# Episode: 80, score: -13.125000
# [-11.  -9. -14. -14. -14. -11. -16. -16.]
# training loop:  20% |########                                   | ETA:  0:30:02
# Episode: 100, score: -13.000000
# [-12. -11. -11. -11. -15. -15. -15. -14.]
# training loop:  24% |##########                                 | ETA:  0:28:32
# Episode: 120, score: -13.375000
# [-14. -12. -15. -13. -15. -10. -14. -14.]
# training loop:  28% |############                               | ETA:  0:27:03
# Episode: 140, score: -13.625000
# [ -9. -15. -15. -14. -15. -15. -15. -11.]
# training loop:  32% |#############                              | ETA:  0:25:33
# Episode: 160, score: -12.250000
# [-14. -13. -14. -11. -16.  -7. -16.  -7.]
# training loop:  36% |###############                            | ETA:  0:24:02
# Episode: 180, score: -14.250000
# [-16. -15. -14. -13. -16. -15. -15. -10.]
# training loop:  40% |#################                          | ETA:  0:22:32
# Episode: 200, score: -11.750000
# [-13. -13. -13. -11. -11. -10.  -9. -14.]
# training loop:  44% |##################                         | ETA:  0:21:01
# Episode: 220, score: -13.125000
# [-14. -12. -13. -12. -12. -12. -16. -14.]
# training loop:  48% |####################                       | ETA:  0:19:31
# Episode: 240, score: -13.375000
# [-14. -13. -14. -11. -12. -15. -15. -13.]
# training loop:  52% |######################                     | ETA:  0:18:01
# Episode: 260, score: -14.125000
# [-12. -16. -14. -15. -13. -14. -15. -14.]
# training loop:  56% |########################                   | ETA:  0:16:31
# Episode: 280, score: -14.125000
# [-14. -15. -13. -13. -16. -15. -14. -13.]
# training loop:  60% |#########################                  | ETA:  0:15:01
# Episode: 300, score: -12.250000
# [ -8.  -9. -13. -14. -11. -12. -15. -16.]
# training loop:  64% |###########################                | ETA:  0:13:31
# Episode: 320, score: -11.375000
# [-12. -10. -14.  -9. -10. -12. -14. -10.]
# training loop:  68% |#############################              | ETA:  0:12:01
# Episode: 340, score: -12.750000
# [-13. -11. -15. -15.  -9. -10. -15. -14.]
# training loop:  72% |##############################             | ETA:  0:10:30
# Episode: 360, score: -14.000000
# [-15. -14. -15. -13. -14. -16. -11. -14.]
# training loop:  76% |################################           | ETA:  0:09:00
# Episode: 380, score: -13.000000
# [-12.  -6. -14. -16. -15. -15. -14. -12.]
# training loop:  80% |##################################         | ETA:  0:07:30
# Episode: 400, score: -13.000000
# [ -9.  -9. -16. -15. -14. -12. -15. -14.]
# training loop:  84% |####################################       | ETA:  0:06:00
# Episode: 420, score: -14.375000
# [-14. -16. -14. -16. -13. -11. -15. -16.]
# training loop:  88% |#####################################      | ETA:  0:04:30
# Episode: 440, score: -14.500000
# [-15. -16. -15. -14. -15. -15. -11. -15.]
# training loop:  92% |#######################################    | ETA:  0:03:00
# Episode: 460, score: -13.500000
# [-13. -12. -15. -14. -11. -16. -16. -11.]
# training loop:  96% |#########################################  | ETA:  0:01:30
# Episode: 480, score: -12.250000
# [-11. -15. -12.  -9. -11. -12. -15. -13.]
# training loop: 100% |###########################################| Time: 0:37:33
# Episode: 500, score: -13.375000
# [-11. -15. -12. -14. -14. -13. -14. -14.]

# %%
# play game after training!
pong_utils.play(env, policy, time=2000)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgUXSPPYALWUUYUXLE">
#     <br>
#     <input id="_anim_sliderUXSPPYALWUUYUXLE" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animUXSPPYALWUUYUXLE.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animUXSPPYALWUUYUXLE.slower()">&#8211;</button>
#     <button onclick="animUXSPPYALWUUYUXLE.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animUXSPPYALWUUYUXLE.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animUXSPPYALWUUYUXLE.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animUXSPPYALWUUYUXLE.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animUXSPPYALWUUYUXLE.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animUXSPPYALWUUYUXLE.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animUXSPPYALWUUYUXLE.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animUXSPPYALWUUYUXLE.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectUXSPPYALWUUYUXLE" class="anim_control">
#     <input type="radio" name="state" value="once" checked> Once </input>
#     <input type="radio" name="state" value="loop" > Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgUXSPPYALWUUYUXLE";
#     var slider_id = "_anim_sliderUXSPPYALWUUYUXLE";
#     var loop_select_id = "_anim_loop_selectUXSPPYALWUUYUXLE";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %%
plt.plot(mean_rewards)

# %%
# save your policy!
torch.save(policy, 'REINFORCE_00.policy')

# load your policy if needed
# policy = torch.load('REINFORCE.policy')

# try and test out the solution!
# policy = torch.load('PPO_solution.policy')

# %%
from parallelEnv import parallelEnv
import numpy as np
# WARNING: running through all 800 episodes will take 30-45 minutes

# training loop max iterations
episode = 1000

# widget bar to display progress
# !pip install progressbar
import progressbar as pb
widget = ['training loop: ', pb.Percentage(), ' ', 
          pb.Bar(), ' ', pb.ETA() ]
timer = pb.ProgressBar(widgets=widget, maxval=episode).start()

# initialize environment
envs = parallelEnv('PongDeterministic-v4', n=8, seed=1234)

discount_rate = .99
beta = .01
tmax = 50

# keep track of progress
#mean_rewards = []

for e in range(episode):

    # collect trajectories
    old_probs, states, actions, rewards = \
        pong_utils.collect_trajectories(envs, policy, tmax=tmax)
        
    total_rewards = np.sum(rewards, axis=0)

    # this is the SOLUTION!
    # use your own surrogate function
    L = -surrogate(policy, old_probs, states, actions, rewards, beta=beta)
    
    # L = -pong_utils.surrogate(policy, old_probs, states, actions, rewards, beta=beta)
    optimizer.zero_grad()
    L.backward()
    optimizer.step()
    del L
        
    # the regulation term also reduces
    # this reduces exploration in later runs
    beta*=.995
    
    # get the average reward of the parallel environments
    mean_rewards.append(np.mean(total_rewards))
    
    # display some progress every 20 iterations
    if (e+1)%20 ==0 :
        print("Episode: {0:d}, score: {1:f}".format(e+1,np.mean(total_rewards)))
        print(total_rewards)
        
    # update progress widget bar
    timer.update(e+1)
    
timer.finish()
# Out:
# Requirement already satisfied: progressbar in /opt/conda/lib/python3.6/site-packages (2.5)
# training loop:   1% |                                           | ETA:  0:16:46
# Episode: 20, score: -1.750000
# [-2. -2. -2. -2. -2.  0. -2. -2.]
# training loop:   3% |#                                          | ETA:  0:14:50
# Episode: 40, score: -1.750000
# [-2. -2. -2. -2. -2. -2.  0. -2.]
# training loop:   5% |##                                         | ETA:  0:14:03
# Episode: 60, score: -1.625000
# [-2. -2. -2. -1. -1. -2. -2. -1.]
# training loop:   7% |###                                        | ETA:  0:13:30
# Episode: 80, score: -1.750000
# [-2. -2. -1. -2. -2. -1. -2. -2.]
# training loop:   9% |####                                       | ETA:  0:13:05
# Episode: 100, score: -1.250000
# [ 0. -2. -1. -1. -2. -2. -2.  0.]
# training loop:  11% |#####                                      | ETA:  0:12:42
# Episode: 120, score: -1.750000
# [-2. -2. -2.  0. -2. -2. -2. -2.]
# training loop:  13% |#####                                      | ETA:  0:12:21
# Episode: 140, score: -1.625000
# [-2. -2.  1. -2. -2. -2. -2. -2.]
# training loop:  15% |######                                     | ETA:  0:12:01
# Episode: 160, score: -1.125000
# [-2. -2. -2.  0. -1.  1. -2. -1.]
# training loop:  17% |#######                                    | ETA:  0:11:42
# Episode: 180, score: -1.375000
# [-2.  1. -1. -2. -2. -2. -2. -1.]
# training loop:  19% |########                                   | ETA:  0:11:24
# Episode: 200, score: -1.625000
# [ 1. -2. -2. -2. -2. -2. -2. -2.]
# training loop:  21% |#########                                  | ETA:  0:11:05
# Episode: 220, score: -1.500000
# [-1. -2. -2. -1. -1. -1. -2. -2.]
# training loop:  23% |##########                                 | ETA:  0:10:47
# Episode: 240, score: -2.000000
# [-2. -2. -2. -2. -2. -2. -2. -2.]
# training loop:  25% |###########                                | ETA:  0:10:29
# Episode: 260, score: -1.375000
# [-2. -1. -1. -1. -2. -2. -1. -1.]
# training loop:  27% |###########                                | ETA:  0:10:11
# Episode: 280, score: -1.625000
# [-2. -1. -2. -1. -2. -2. -2. -1.]
# training loop:  29% |############                               | ETA:  0:09:54
# Episode: 300, score: -1.875000
# [-2. -1. -2. -2. -2. -2. -2. -2.]
# training loop:  31% |#############                              | ETA:  0:09:36
# Episode: 320, score: -1.375000
# [-2. -1. -2. -2.  0.  0. -2. -2.]
# training loop:  33% |##############                             | ETA:  0:09:19
# Episode: 340, score: -1.875000
# [-2. -2. -2. -2. -2. -2. -2. -1.]
# training loop:  35% |###############                            | ETA:  0:09:02
# Episode: 360, score: -1.625000
# [-1. -2. -2. -2. -1. -2. -1. -2.]
# training loop:  37% |################                           | ETA:  0:08:45
# Episode: 380, score: -1.500000
# [-1. -2. -1. -1. -2. -1. -2. -2.]
# training loop:  39% |#################                          | ETA:  0:08:27
# Episode: 400, score: -1.500000
# [-1. -2. -2. -2. -2. -2.  1. -2.]
# training loop:  41% |##################                         | ETA:  0:08:10
# Episode: 420, score: -1.500000
# [-2. -1. -1. -2. -1. -1. -2. -2.]
# training loop:  43% |##################                         | ETA:  0:07:53
# Episode: 440, score: -1.750000
# [-2. -2. -2. -2.  0. -2. -2. -2.]
# training loop:  45% |###################                        | ETA:  0:07:36
# Episode: 460, score: -1.750000
# [-2. -1. -2. -2. -1. -2. -2. -2.]
# training loop:  47% |####################                       | ETA:  0:07:19
# Episode: 480, score: -1.750000
# [-2. -2. -2. -2. -2.  0. -2. -2.]
# training loop:  49% |#####################                      | ETA:  0:07:02
# Episode: 500, score: -1.500000
# [ 0. -1. -2. -2. -2. -1. -2. -2.]
# training loop:  51% |######################                     | ETA:  0:06:45
# Episode: 520, score: -1.875000
# [-2. -2. -2. -2. -2. -2. -1. -2.]
# training loop:  53% |#######################                    | ETA:  0:06:28
# Episode: 540, score: -1.500000
# [-2.  0. -2. -1. -2. -1. -2. -2.]
# training loop:  55% |########################                   | ETA:  0:06:11
# Episode: 560, score: -1.875000
# [-2. -2. -2. -2. -2. -2. -2. -1.]
# training loop:  57% |########################                   | ETA:  0:05:54
# Episode: 580, score: -1.750000
# [-2. -2. -2.  0. -2. -2. -2. -2.]
# training loop:  59% |#########################                  | ETA:  0:05:37
# Episode: 600, score: -1.750000
# [-2. -2. -1. -2. -2. -2. -1. -2.]
# training loop:  61% |##########################                 | ETA:  0:05:20
# Episode: 620, score: -1.625000
# [-2. -1. -2. -2. -2. -2.  0. -2.]
# training loop:  63% |###########################                | ETA:  0:05:04
# Episode: 640, score: -1.750000
# [-2. -2. -2. -2. -1. -2. -2. -1.]
# training loop:  65% |############################               | ETA:  0:04:47
# Episode: 660, score: -2.000000
# [-2. -2. -2. -2. -2. -2. -2. -2.]
# training loop:  67% |#############################              | ETA:  0:04:30
# Episode: 680, score: -1.625000
# [-2. -2. -2. -2. -2. -1. -1. -1.]
# training loop:  69% |##############################             | ETA:  0:04:13
# Episode: 700, score: -1.875000
# [-1. -2. -2. -2. -2. -2. -2. -2.]
# training loop:  71% |##############################             | ETA:  0:03:56
# Episode: 720, score: -1.875000
# [-2. -2. -1. -2. -2. -2. -2. -2.]
# training loop:  73% |###############################            | ETA:  0:03:39
# Episode: 740, score: -1.375000
# [-2. -2. -2. -2.  0. -2.  1. -2.]
# training loop:  75% |################################           | ETA:  0:03:22
# Episode: 760, score: -1.750000
# [-1. -2. -1. -2. -2. -2. -2. -2.]
# training loop:  77% |#################################          | ETA:  0:03:06
# Episode: 780, score: -1.625000
# [-1. -1. -2. -2. -2. -1. -2. -2.]
# training loop:  79% |##################################         | ETA:  0:02:49
# Episode: 800, score: -1.625000
# [-1. -2.  0. -2. -2. -2. -2. -2.]
# training loop:  81% |###################################        | ETA:  0:02:32
# Episode: 820, score: -1.500000
# [-2. -2. -2.  1. -2. -2. -1. -2.]
# training loop:  83% |####################################       | ETA:  0:02:15
# Episode: 840, score: -1.875000
# [-2. -2. -2. -2. -2. -2. -1. -2.]
# training loop:  85% |####################################       | ETA:  0:01:58
# Episode: 860, score: -1.625000
# [-2. -1. -2. -1. -2. -2. -2. -1.]
# training loop:  87% |#####################################      | ETA:  0:01:41
# Episode: 880, score: -1.625000
# [-1. -2. -1. -2. -2. -2. -2. -1.]
# training loop:  89% |######################################     | ETA:  0:01:24
# Episode: 900, score: -1.500000
# [-2. -2. -1. -1. -1. -2. -1. -2.]
# training loop:  91% |#######################################    | ETA:  0:01:08
# Episode: 920, score: -1.750000
# [-1. -2. -2. -2. -2. -2. -2. -1.]
# training loop:  93% |########################################   | ETA:  0:00:51
# Episode: 940, score: -1.375000
# [-2. -2.  1. -2. -1. -2. -1. -2.]
# training loop:  95% |#########################################  | ETA:  0:00:34
# Episode: 960, score: -1.750000
# [-1. -2. -2. -2. -2. -2. -1. -2.]
# training loop:  97% |########################################## | ETA:  0:00:17
# Episode: 980, score: -1.625000
# [-2. -2. -2. -2. -2. -2.  1. -2.]
# training loop: 100% |###########################################| Time: 0:14:00
# Episode: 1000, score: -1.625000
# [-2. -2. -1. -2. -2. -2.  0. -2.]

# %%
# play game after training!
pong_utils.play(env, policy, time=100)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgNONYVYJXLIOORORK">
#     <br>
#     <input id="_anim_sliderNONYVYJXLIOORORK" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animNONYVYJXLIOORORK.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animNONYVYJXLIOORORK.slower()">&#8211;</button>
#     <button onclick="animNONYVYJXLIOORORK.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animNONYVYJXLIOORORK.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animNONYVYJXLIOORORK.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animNONYVYJXLIOORORK.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animNONYVYJXLIOORORK.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animNONYVYJXLIOORORK.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animNONYVYJXLIOORORK.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animNONYVYJXLIOORORK.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectNONYVYJXLIOORORK" class="anim_control">
#     <input type="radio" name="state" value="once" checked> Once </input>
#     <input type="radio" name="state" value="loop" > Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgNONYVYJXLIOORORK";
#     var slider_id = "_anim_sliderNONYVYJXLIOORORK";
#     var loop_select_id = "_anim_loop_selectNONYVYJXLIOORORK";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6

# %%
plt.plot(mean_rewards)

# %%
# save your policy!
torch.save(policy, 'REINFORCE_01.policy')

# %%
'REINFORCE_0'+str(1)+'.policy'
